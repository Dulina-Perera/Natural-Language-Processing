# %%
import openai
import os
import pandas as pd

from dotenv import load_dotenv
from IPython.display import display
from openai import OpenAI
from openai.pagination import SyncPage

load_dotenv()
# Out:
# True

# %%
client: OpenAI = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

models: list = [
    {
        "id": model.id,
        "created": model.created,
        "object": model.object,
        "owned_by": model.owned_by,
    }
    for model in client.models.list()
]

models_df: pd.DataFrame = pd.DataFrame(models)

display(models_df)
# Out:
#                              id     created object         owned_by
# 0                      dall-e-3  1698785189  model           system
# 1                     whisper-1  1677532384  model  openai-internal
# 2                   davinci-002  1692634301  model           system
# 3                   babbage-002  1692634615  model           system
# 4                      dall-e-2  1698798177  model           system
# 5             gpt-3.5-turbo-16k  1683758102  model  openai-internal
# 6                 tts-1-hd-1106  1699053533  model           system
# 7                      tts-1-hd  1699046015  model           system
# 8            gpt-3.5-turbo-1106  1698959748  model           system
# 9   gpt-3.5-turbo-instruct-0914  1694122472  model           system
# 10       gpt-3.5-turbo-instruct  1692901427  model           system
# 11       text-embedding-3-small  1705948997  model           system
# 12                        tts-1  1681940951  model  openai-internal
# 13           gpt-3.5-turbo-0125  1706048358  model           system
# 14                gpt-3.5-turbo  1677610602  model           openai
# 15           gpt-3.5-turbo-0301  1677649963  model           openai
# 16                   tts-1-1106  1699053241  model           system
# 17       text-embedding-3-large  1705953180  model           system
# 18       gpt-3.5-turbo-16k-0613  1685474247  model           openai
# 19           gpt-3.5-turbo-0613  1686587434  model           openai
# 20       text-embedding-ada-002  1671217299  model  openai-internal

# %%
# Completion API & Chat Completion API
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {
            "role": "assistant",
            "content": "The Los Angeles Dodgers won the World Series in 2020.",
        },
        {"role": "user", "content": "Where was it played?"},
    ],
)

display(response)
